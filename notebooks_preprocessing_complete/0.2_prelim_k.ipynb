# %%
import os
import numpy as np
import pandas as pd
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt

# %% [markdown]
# ## Notebook to transform lithology zone rasters to k arrays
# using k values in `Rondout_Neversink_GeologyLookupTable_jhw.xlsx'`

# %%
method = 'mean' # options: 'mean', 'min', 'max', 'original'

# %%
#  read in k value lookup table to df

#  original table

k_df_original = pd.read_excel(
    '../processed_data/Rondout_Neversink_GeologyLookupTable.xlsx',
    sheet_name='Sheet2'
)
k_df_original.index = k_df_original.Lookup_Code

#  updated values -- use these for starting values
k_df = pd.read_excel(
    '../processed_data/Rondout_Neversink_GeologyLookupTable_jhw.xlsx',
    sheet_name='Sheet2'
)

k_df.index = k_df.Lookup_Code

if method == 'mean':
    print('Using mean K value')
    k_df['Kh_ft_d_mean'] = (k_df['Kh_ft_d_lower'] + k_df['Kh_ft_d_upper']) / 2
    k_df['Kh_m_d'] = k_df['Kh_ft_d_mean'] * 0.3048

if method == 'min':
    print('Using MIN K value')
    k_df['Kh_m_d'] = k_df['Kh_ft_d_lower'] * 0.3048
    
if method == 'max':
    print('Using MAX K value')
    k_df['Kh_m_d'] = k_df['Kh_ft_d_lower'] * 0.3048

if method == 'original':
    print('Using original K values')
    k_df = k_df_original.copy()
    
    
k_df
# Out:
# Using mean K value
#                                                 Geology_Type  Lookup_Code  \
# Lookup_Code
# 11                                                   Outwash           11
# 12                                            Peat & outwash           12
# 13                                           Water & outwash           13
# 14                                              Basal Coarse           14
# 15                                                      Kame           15
# 16                                              Alluvial fan           16
# 17                                        Alluvium & outwash           17
# 18                                              Kame moraine           18
# 19                                              Till moraine           19
# 20                                            Till & Bedrock           20
# 21                                                      Till           21
# 22                                                   Bedrock           22
# 23                                    Lacustrine silt & clay           23
# 24                        Outwash & alluvial fan combination           24
# 25                           Kame & alluvial fan combination           25
# 26                       Peat outwash & alluvium combination           26
# 27                                   Peat & kame combination           27
# 28                               Alluvium & Kame combination           28
# 29                                           Artificial fill           29
# 30                                           Lacustrine Sand           30
# 31                    Lacustrine sand & alluvium combination           31
# 32                                 Till/alluvium combination           32
# 33                lacustrine sand & alluvium fan combination           33
# 34                lacustrine silt & alluvium fan combination           34
# 35           Alluvium & lacustrine silt and clay combination           35
# 36                                   Till & Kame combination           36
# 37                                Till & Outwash combination           37
# 38                                              Kame & Water           38
# 39                                   Peat & Till combination           39
#
#              Kh_ft_d_lower  Kh_ft_d_upper  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# Lookup_Code
# 11                  150.00          250.0         NaN         NaN         NaN
# 12                  150.00          250.0         NaN         NaN         NaN
# 13                  150.00          250.0         NaN         NaN         NaN
# 14                   50.00          100.0         NaN         NaN         NaN
# 15                   50.00          100.0         NaN         NaN         NaN
# 16                   25.00           75.0         NaN         NaN         NaN
# 17                  100.00          200.0         NaN         NaN         NaN
# 18                   10.00           50.0         NaN         NaN         NaN
# 19                    1.00           10.0         NaN         NaN         NaN
# 20                    0.10            1.0         NaN         NaN         NaN
# 21                    0.10            1.0         NaN         NaN         NaN
# 22                    0.10            1.0         NaN         NaN         NaN
# 23                    0.03            0.3         NaN         NaN         NaN
# 24                  100.00          200.0         NaN         NaN         NaN
# 25                   50.00          100.0         NaN         NaN         NaN
# 26                   50.00          100.0         NaN         NaN         NaN
# 27                   50.00          100.0         NaN         NaN         NaN
# 28                   50.00          100.0         NaN         NaN         NaN
# 29                    5.00           20.0         NaN         NaN         NaN
# 30                    5.00           20.0         NaN         NaN         NaN
# 31                    5.00           50.0         NaN         NaN         NaN
# 32                    1.00           10.0         NaN         NaN         NaN
# 33                    5.00           50.0         NaN         NaN         NaN
# 34                    1.00           10.0         NaN         NaN         NaN
# 35                    5.00           50.0         NaN         NaN         NaN
# 36                   10.00           50.0         NaN         NaN         NaN
# 37                   10.00           50.0         NaN         NaN         NaN
# 38                   50.00          100.0         NaN         NaN         NaN
# 39                    0.10            1.0         NaN         NaN         NaN
#
#              Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# Lookup_Code
# 11                  NaN         NaN         NaN          NaN          NaN
# 12                  NaN         NaN         NaN          NaN          NaN
# 13                  NaN         NaN         NaN          NaN          NaN
# 14                  NaN         NaN         NaN          NaN          NaN
# 15                  NaN         NaN         NaN          NaN          NaN
# 16                  NaN         NaN         NaN          NaN          NaN
# 17                  NaN         NaN         NaN          NaN          NaN
# 18                  NaN         NaN         NaN          NaN          NaN
# 19                  NaN         NaN         NaN          NaN          NaN
# 20                  NaN         NaN         NaN          NaN          NaN
# 21                  NaN         NaN         NaN          NaN          NaN
# 22                  NaN         NaN         NaN          NaN          NaN
# 23                  NaN         NaN         NaN          NaN          NaN
# 24                  NaN         NaN         NaN          NaN          NaN
# 25                  NaN         NaN         NaN          NaN          NaN
# 26                  NaN         NaN         NaN          NaN          NaN
# 27                  NaN         NaN         NaN          NaN          NaN
# 28                  NaN         NaN         NaN          NaN          NaN
# 29                  NaN         NaN         NaN          NaN          NaN
# 30                  NaN         NaN         NaN          NaN          NaN
# 31                  NaN         NaN         NaN          NaN          NaN
# 32                  NaN         NaN         NaN          NaN          NaN
# 33                  NaN         NaN         NaN          NaN          NaN
# 34                  NaN         NaN         NaN          NaN          NaN
# 35                  NaN         NaN         NaN          NaN          NaN
# 36                  NaN         NaN         NaN          NaN          NaN
# 37                  NaN         NaN         NaN          NaN          NaN
# 38                  NaN         NaN         NaN          NaN          NaN
# 39                  NaN         NaN         NaN          NaN          NaN
#
#              Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Kh_ft_d_mean  \
# Lookup_Code
# 11                   NaN          NaN          NaN          NaN       200.000
# 12                   NaN          NaN          NaN          NaN       200.000
# 13                   NaN          NaN          NaN          NaN       200.000
# 14                   NaN          NaN          NaN          NaN        75.000
# 15                   NaN          NaN          NaN          NaN        75.000
# 16                   NaN          NaN          NaN          NaN        50.000
# 17                   NaN          NaN          NaN          NaN       150.000
# 18                   NaN          NaN          NaN          NaN        30.000
# 19                   NaN          NaN          NaN          NaN         5.500
# 20                   NaN          NaN          NaN          NaN         0.550
# 21                   NaN          NaN          NaN          NaN         0.550
# 22                   NaN          NaN          NaN          NaN         0.550
# 23                   NaN          NaN          NaN          NaN         0.165
# 24                   NaN          NaN          NaN          NaN       150.000
# 25                   NaN          NaN          NaN          NaN        75.000
# 26                   NaN          NaN          NaN          NaN        75.000
# 27                   NaN          NaN          NaN          NaN        75.000
# 28                   NaN          NaN          NaN          NaN        75.000
# 29                   NaN          NaN          NaN          NaN        12.500
# 30                   NaN          NaN          NaN          NaN        12.500
# 31                   NaN          NaN          NaN          NaN        27.500
# 32                   NaN          NaN          NaN          NaN         5.500
# 33                   NaN          NaN          NaN          NaN        27.500
# 34                   NaN          NaN          NaN          NaN         5.500
# 35                   NaN          NaN          NaN          NaN        27.500
# 36                   NaN          NaN          NaN          NaN        30.000
# 37                   NaN          NaN          NaN          NaN        30.000
# 38                   NaN          NaN          NaN          NaN        75.000
# 39                   NaN          NaN          NaN          NaN         0.550
#
#                 Kh_m_d
# Lookup_Code
# 11           60.960000
# 12           60.960000
# 13           60.960000
# 14           22.860000
# 15           22.860000
# 16           15.240000
# 17           45.720000
# 18            9.144000
# 19            1.676400
# 20            0.167640
# 21            0.167640
# 22            0.167640
# 23            0.050292
# 24           45.720000
# 25           22.860000
# 26           22.860000
# 27           22.860000
# 28           22.860000
# 29            3.810000
# 30            3.810000
# 31            8.382000
# 32            1.676400
# 33            8.382000
# 34            1.676400
# 35            8.382000
# 36            9.144000
# 37            9.144000
# 38           22.860000
# 39            0.167640

# %% [markdown]
# ### Just out of curiousity, plot the difference between new and original K values

# %%
compare = k_df.join(k_df_original, rsuffix='_original')
compare = compare[['Geology_Type', 'Kh_m_d', 'Kh_m_d_original']]
compare['diff'] = compare['Kh_m_d'] - compare['Kh_m_d_original']
compare
# Out:
#                                                 Geology_Type     Kh_m_d  \
# Lookup_Code
# 11                                                   Outwash  60.960000
# 12                                            Peat & outwash  60.960000
# 13                                           Water & outwash  60.960000
# 14                                              Basal Coarse  22.860000
# 15                                                      Kame  22.860000
# 16                                              Alluvial fan  15.240000
# 17                                        Alluvium & outwash  45.720000
# 18                                              Kame moraine   9.144000
# 19                                              Till moraine   1.676400
# 20                                            Till & Bedrock   0.167640
# 21                                                      Till   0.167640
# 22                                                   Bedrock   0.167640
# 23                                    Lacustrine silt & clay   0.050292
# 24                        Outwash & alluvial fan combination  45.720000
# 25                           Kame & alluvial fan combination  22.860000
# 26                       Peat outwash & alluvium combination  22.860000
# 27                                   Peat & kame combination  22.860000
# 28                               Alluvium & Kame combination  22.860000
# 29                                           Artificial fill   3.810000
# 30                                           Lacustrine Sand   3.810000
# 31                    Lacustrine sand & alluvium combination   8.382000
# 32                                 Till/alluvium combination   1.676400
# 33                lacustrine sand & alluvium fan combination   8.382000
# 34                lacustrine silt & alluvium fan combination   1.676400
# 35           Alluvium & lacustrine silt and clay combination   8.382000
# 36                                   Till & Kame combination   9.144000
# 37                                Till & Outwash combination   9.144000
# 38                                              Kame & Water  22.860000
# 39                                   Peat & Till combination   0.167640
#
#              Kh_m_d_original        diff
# Lookup_Code
# 11                   175.000 -114.040000
# 12                   175.000 -114.040000
# 13                   175.000 -114.040000
# 14                   175.000 -152.140000
# 15                    19.812    3.048000
# 16                    12.192    3.048000
# 17                    12.192   33.528000
# 18                    19.812  -10.668000
# 19                    86.400  -84.723600
# 20                    86.400  -86.232360
# 21                    86.400  -86.232360
# 22                     1.000   -0.832360
# 23                    86.400  -86.349708
# 24                   175.000 -129.280000
# 25                    80.000  -57.140000
# 26                    80.000  -57.140000
# 27                    80.000  -57.140000
# 28                    80.000  -57.140000
# 29                    80.000  -76.190000
# 30                     2.000    1.810000
# 31                    80.000  -71.618000
# 32                    80.000  -78.323600
# 33                    80.000  -71.618000
# 34                    80.000  -78.323600
# 35                    80.000  -71.618000
# 36                    80.000  -70.856000
# 37                    80.000  -70.856000
# 38                    80.000  -57.140000
# 39                    80.000  -79.832360

# %%
def zone2k(layer,k_df,new_version=True):
    # function to make horizontal and vertical k rasters from lith rasters 
    if new_version:
        k_str = '../source_data/Shapefiles/Layers_and_Zones/K_ZONES/L{}_K_Zone_50mGrid.tif'
    else:
        k_str = '../source_data/Shapefiles/Layers_and_Zones/K_ZONES/V2_Layer{}_K.tif'
    
    print('    loading: {}'.format(k_str.format(layer+1)))
    
    with rasterio.open(k_str.format(layer+1)) as src:
        crs = src.crs
        meta = src.meta
        nodata = meta['nodata']
        K_tuple = src.read(1, masked=True),
        K_data = K_tuple[0].data.astype(float)

        
    newK = K_data.copy()


    for idx in k_df.index:
        newK[newK==idx] = k_df.loc[idx].Kh_m_d   
    newKv = newK / 10.0

    #  write out newK to geotiff in processed_input dir

    outfile = 'Layer{}_Kh.tif'.format(layer+1)
    outdir = '../processed_data/'

    outpath = os.path.join(outdir, outfile)

    dataset = rasterio.open(
        outpath, 
        'w', 
        driver=meta['driver'],
        height = newK.shape[0], 
        width = newK.shape[1],
        count=1,
        nodata = nodata,
        dtype=str(newK.dtype),
        crs = crs,
        compress='lzw',
        transform=meta['transform']
    )
    
    print('    writing: {}'.format(outpath))
    dataset.write(newK, 1)
    dataset.close()

    # write out newKv to geotiff in processed_input dir

    outfile = 'Layer{}_Kv.tif'.format(layer+1)
    outdir = '../processed_data/'

    outpath = os.path.join(outdir, outfile)

    dataset = rasterio.open(
        outpath, 
        'w', 
        driver=meta['driver'],
        height = newKv.shape[0], 
        width = newKv.shape[1],
        count=1,
        nodata = nodata / 10.0,
        dtype=str(newKv.dtype),
        crs = crs,
        compress='lzw',
        transform=meta['transform']
    )

    print('    writing: {}'.format(outpath))
    dataset.write(newKv, 1)
    dataset.close()

# %% [markdown]
# ### Make K arrays, save to processed_data

# %%
for i in range(4):
    print('now on layer {}'.format(i + 1))
    zone2k(i, k_df)
# Out:
# now on layer 1
#     loading: ../source_data/Shapefiles/Layers_and_Zones/K_ZONES/L1_K_Zone_50mGrid.tif
#     writing: ../processed_data/Layer1_Kh.tif
#     writing: ../processed_data/Layer1_Kv.tif
# now on layer 2
#     loading: ../source_data/Shapefiles/Layers_and_Zones/K_ZONES/L2_K_Zone_50mGrid.tif
#     writing: ../processed_data/Layer2_Kh.tif
#     writing: ../processed_data/Layer2_Kv.tif
# now on layer 3
#     loading: ../source_data/Shapefiles/Layers_and_Zones/K_ZONES/L3_K_Zone_50mGrid.tif
#     writing: ../processed_data/Layer3_Kh.tif
#     writing: ../processed_data/Layer3_Kv.tif
# now on layer 4
#     loading: ../source_data/Shapefiles/Layers_and_Zones/K_ZONES/L4_K_Zone_50mGrid.tif
#     writing: ../processed_data/Layer4_Kh.tif
#     writing: ../processed_data/Layer4_Kv.tif
